# %% [markdown]
# ## Assessment Task 3: In-class Project
#
# ### Introduction
# In this project, you'll navigate the complete data analysis process, from defining the problem to presenting your findings. You'll gain practical experience in handling real-wrld data and using various tools and technologies. Here are your instructions for each phase of the project:
#
# **Design Brief**: Identify a complex societal issue (e.g. housing, natural disasters) or a need within the school
# community. Form a hypothesis related to the issue. Design a system that processes and visualises data to test
# your hypothesis.
#
# **Phase 1: Identifying and Defining**
# Consider a wicked problem in society (e.g. housing crisis, bushfires, floods), or alternatively, a need or opportunity
# in the school community.
# - **Mind Map**: Draw a three-tiered mind map of data you could collect to investigate either from a publicly
# available dataset, or your own primary research (if looking at school community). On the 2nd tier put the
# wicked problems, on the 3rd tier get more specific on each problem.
#
# - **Define Your Purpose**: Before finding a dataset or collecting data, develop a hypothesis on a specific area.
#
# - **Requirements Outline**: List down the functional (what your project should do) and non-functional
# (qualities like speed or security) requirements for your project. Be specific.
#
# ---
#
# **Phase 2: Researching and Planning**
# - Research Your Chosen Issue: What’s already available on the topic? Find news articles, journal articles, or
# interview students / teachers (if local issue) to get a sense of what people think of the topic.
#
# - **Discuss the findings**: Discuss the above information in at least one SEE-I paragraph.
#
# - **Find Your Data**: Acquire any data you need, whether it be through [https://www.kaggle.com/] (Secondary
# Research), Google Forms (Primary Research) or another source.
#
# - **Planning**: Create a data dictionary to show the type of data and parameters required for your dataset.
#
# ---
#
# **Phase 3: Producing and Implementing**
# - **Python, Pandas and Matplotlib**: Use Python Pandas to read and manipulate data. Create relevant charts
# and visualisations using Matplotlib.
#
# - **User Interface**: How does the user find and generate the data to assess your findings? In a separate
# Python program, create an intuitive text-based or graphical user interface (GUI) which allows for an
# accessible User Experience (UX). Call the program ‘main.py’ for the user interface, then move any
# functions to another file to import (e.g. ‘bushfire_data.py’).
#     - **Note**: When you move over to the .py files, if you need to output a dataframe **you need to
# remember to use the print function**, for example:
#     - ```print(big_mac_df)```
#
# ---
#
# **Phase 4: Testing and Evaluating**
# - **Analyse and Conclude**: Analyse your findings using **at least one SEE-I paragraph**. If you spot areas needing
# more research, make a note of them in your findings. Make sure to provide a **conclusion** on your
# hypothesis.
#
# - **Test Your Analysis**: Make sure your analysis works correctly. Check and double-check your algorithms to
# ensure they provide accurate results.
#
# - **Peer Verification**: Exchange your work with a classmate. Verify each other's datasets, calculations, and
# outputs. Provide feedback – PMI tables are helpful here (Plus, Minus, Implication).
#
# - **Evaluate your project**:
#     - Evaluate your system and results in relation to your **Requirements Outline**.
#     - Evaluate your system in relation to **peer feedback**.
#     - Evaluate your project in relation to **project management**.
#     - Evaluate your system in in relation to its **data and security**. Is the data valid, accurate and timely?
# Is it unbiased? Do we need to improve its security – if so, how? Could the UX be more accessible –
# how?
#
# **Project Deliverables**:
# - 1. **Markdown (.md) File**: You should have a well-documented Markdown file that showcases your entire
# project, including all planning, research, production, implementation, testing and evaluating.
#
# - 2. **Dataset**: Provide any datasets which are relevant to your chosen data scenario.
#
# - 3. **Visualisations**: Include data visualisations and plots that support your analysis.
#
# - 4. **User Interface**: The user must be able to interact with the program in some capacity, either through a
# graphical user interface (GUI), ASCII user interface or text-based user interface.
#
# - 5. **Evaluation**: Write a detailed report evaluating your project against the criteria mentioned earlier.
#
# - 6. **Peer Reviews**: Don't forget to provide feedback on your classmates' projects.
# ---

# %% [markdown]
# ## **Phase 1**
#
# **Wicked problem in society** : Does excessive gaming as a high school student in America leads to bad marks?
#
# ![3-tiered mind map.excalidraw.png](<attachment:3-tiered mind map.excalidraw.png>)
#
# ### **Requirements Outline**
#
# #### **Functional Requirements**
# - Clearly define the business or research problem to be solved
# - Identify the objectives and scope of the analysis
# - Specify key questions to be answered through data
# - Acquire real-world datasets from reliable sources (e.g., CSV, Excel, APIs, databases)
# - Validate the relevance and quality of the data for the defined problem.
# - Use Python for scripting and analysis
# - Create comments and summarisation for datas
# - Identify patterns, trends, and outliers
# - Visualise data using ```matplotlib``` and ```pandas```
#
# #### **Non-functional Requirements**
# - The final report should be clear, visually appealing, and understandable
# - All codes and pictures should be able to run perfectly without any bugs or glitches
# - The analysis should have only consistent and accurate results across multiple runs
# - All data is precise and accurate for user's preferences
#
# ---
#
# #### **Use-Case**
#
# **Actor:** Students
#
# **Goal:** To enable the user to explore, analyze, and modify data related to excessive gaming
#
# **Preconditions:**
# - All required libraries or dependencies (e.g., ```matplotlib``` and ```pandas```) are installed and functioning.
# - The user has basic knowledge of how to navigate the menu and input commands.
# - The dataset includes student scores, game results and statistics in school has been preloaded or is accessible via this dataset.
# - The system is operational and functioning correctly
# - The user understands the structure of the dataset (e.g., column names, data types).
#
# **Main Flow:**
# 1. User launches the program via Visual Studio Code
# 2. System displays a text-based menu including:
#     - ```.csv``` file
#     - Viewing data in graphs (e.g pie, column, line)
#     - Search or filter data to look for specific statistics
#     - Update a data entry (e.g., change a value or correct an error)
# 3. System performs the requested action and outputs to user.
#
# **Postconditions**
# - Any valid updates are saved by the system.
# - Data is available for further queries or analysis.

# %% [markdown]
# ---
#
# ## **Phase Two**
#
# #### **Research (Does excessive gaming as a high school student in America leads to bad marks?)**
#
# ##### **What type of games are most commonly played?**
# Most common types of games people are addicted to includes:
# - **MMO (massively multiplayer online games):** MMOs features virtual worlds where players cooperate or compete against each other.
# - **MMORPG (massively multiplayer online role-playing games):** a subgenre of MMOs, MMORPGs allow players to role-play as their own characters in massive virtual worlds where they cooperate or compete against each other.
# - **MOBA (multiplayer online battle arenas):** MOBAs involve two teams of online players competing against each other, with every player controlling a character with unique abilities.
# - **Battle Royale:** online multiplayer games where players fight one another to see who stands last.
# - **First-Person Shooters (FPS):** games focused on gun fighting and other weapon-based combat seen from a first-person perspective.
# - **Online Casino Games:** online games where players place gamble on casino games such as blackjack and roulette, sometimes against a computer or other real people.
#
# According to **data from Statistica**, American gamers have reported that they've spent over 20 hours per week on the following games:
# - 21% on MMORPG (massively multiplayer online role-playing games)
# - 21% on MOBA (multiplayer online battle arenas)
# - 19% on MMO (massively multiplayer online games)
# - 39% on other types of games
#
# ---
#
# ##### **What game genre leads to the worst marks?**
# National Institutes of Health shows the game genres being problematic for school students:
# **MMORPG**
# - Designed to be highly engaging
# - Studies found that people playing these types of games for example World of Warcraft spends more time playing, have worse sleeping quality, and interference to schoolwork as well as socialising compared to other genres.
# - Time commitment in gaming having a negative acadamic impact in school
#
# **Violent Games**
# - Not all games are problematic, some relates to physical aggression though not linking with school marks
# - Behavioural issues
#
# **Exploitative Games**
# - These type of games includes 'lootboxes' or 'chests' designed for people to spend money or time similarly connected to gambling
#
#
# Though not all games are bad for you, mainly theses games above are most likely to ruin academics, socialising, health problems, and
# behavioural issues. It is recommended to encourage healthy gaming habits to prevent issues from happening.
#
# ---
#
# ##### **What are students' sleeping patterns?**
# National Institutes of Health collect information from 200 different articles that specifically focuses on gaming sleep quality. The National Institutes of Health states that out of 20 people being tested, 4 of them are affected due to excessive gaming or gaming close to bedtime. That is 1 out of 5 people negatively affected due to gaming! These students tend to have a harder time sleeping due to the interference with melatonin production, a hormone that is crucial for regulating the body's sleep-wake cycle as said in **Quora**. Best way to prevent poor sleep quality is by taking a break from gaming 1-2 hours before sleeping so that the brain can relax and can stimulate smoothly in darkness.
#
# ---
#
# ##### **Who sleeps more, boys or girls?**
# NIH (National Institutes of Health) shows that girls sleep more when doing excessive gaming or gaming near sleeping time and tends to sleep more compared to boys.
#
#
# ![image.png](attachment:image.png)
#
# ---
#
# #### **Do gaming kids have poorer school attendance?**
# Many articles reveals that excessive video game play may be linked to lower school attendance and academic performance in children, especially when it disrupts sleep and homework. However, moderate/normal gaming isn't shown to cause harm or negative impact in school and may even boost cognitive skills. The key issue is poor screen time boundaries, not gaming itself. To summarise, only a percentage of school students that have poorer attendance due to variety of reasons including gaming.
#
# ---
#
# #### **How many days EXACTLY?**
# Research does show a concerning link between excessive gaming and chronic absenteeism. Chronic absenteeism is defined as missing 10% or more of school days—roughly 18 days per year in most districts. Students who game more than 5 hours per weekday are absent six times more than those who game less than 1 hour. In interviews, 40% of heavy gamers admitted skipping school to play new releases or participate in online events.
#
# ---
#
# #### OTHER RESEARCH ON GAMING
# One study backed by the National Institutes of Health (NIH) examined almost 2,000 kids aged 9 to 10. It was found that the children who spent three or more hours a day playing video games performed better on tests that assessed their ability to control their impulses and remember things compared to kids who did not play games. Brain scans even revealed more activity in the parts of their brains that handle attention and memory. Therefore, it appears that gaming may be beneficial for kids' brains.
#
# It's not just kids who may benefit from a brain boost from games. The National Institute on Aging conducted research into how video games affect older individuals' memories. They had people between 60 and 80 years old play games like Super Mario™ and Angry Birds for about 30 to 45 minutes each day for a month. The individuals playing those engaging games remembered things better than those who played simple games like Solitaire. This suggests that being in new and interesting situations may be beneficial for keeping the older brain. Check out the National Institute on Aging website for the full report.
#
# Globally, the gaming industry was massive in 2023, reaching $184 billion. The typical gamer is approximately 35 years old, and the demographic is almost split down the middle between guys and girls, with about 45% being female and 55% being male. Some of the most popular games include action, shooter, and role-playing games, catering to a wide range of interests.
#
# However, it's essential to remember not to pl  ay video games excessively. While some gaming can be good for the brain, excessive gaming has been tied   to problems with attention and poor mental health. The key is to maintain a balance and continue learning more regarding how the brain is affected by gaming.
#
# ---
#
# #### **DISCUSS THE FINDINGS**
# Gaming can have both positive and negative effects on cognitive development, academic performance, and sleep quality, depending on the type and amount of play. While studies from the National Institutes of Health (NIH) show that children who play video games for three or more hours a day may perform better on cognitive tasks, other research highlights that excessive gaming—especially with genres like MMORPGs, violent games, and exploitative lootbox-based games—can lead to poor sleep, lower school attendance, and behavioral issues. Girls tend to sleep more than boys after gaming, but both are affected when gaming occurs close to bedtime due to melatonin disruption. For instance, NIH research found that 1 in 5 students had disrupted sleep due to gaming, and heavy gamers were absent from school six times more than light gamers. On the other hand, older adults who played immersive games like Super Mario™ showed improved memory, suggesting that gaming can stimulate the brain when done in moderation. Gaming is like a powerful tool, it can sharpen the mind when used wisely, but if misused, it can dull focus, disrupt sleep, and interfere with learning. Just as a hammer can build or break, gaming’s impact depends on how and when it’s used.
#
# ---
#
# #### **Data Dictionary**
# #### 🎮 Gaming Behaviours Dataset – Data Dictionary
#
# | **Variable Name**        | **Data Type** | **Description**                                                                 |
# |--------------------------|---------------|---------------------------------------------------------------------------------|
# | `gamer_id`               | String        | Unique identifier for each gamer                                               |
# | `age`                    | Integer       | Age of the gamer                                                               |
# | `gender`                 | String        | Gender identity (e.g., Male, Female, Non-binary, Prefer not to say)            |
# | `country`                | String        | Country of residence                                                           |
# | `platform`               | String        | Primary gaming platform (e.g., PC, Console, Mobile)                            |
# | `hours_per_week`         | Float         | Average number of hours spent gaming per week                                  |
# | `favorite_genre`         | String        | Gamer’s preferred game genre (e.g., FPS, RPG, Strategy, Simulation)            |
# | `multiplayer_preference` | Boolean       | Whether the gamer prefers multiplayer games (`True` or `False`)                |

# %% [markdown]
# ## **Phase 3**

# %%
# THE CODE CAN ALSO BE FOUND IN A SEPERATE FILE :)
import pandas as pd
import matplotlib.pyplot as plt

DATA_PATH = "Gaming_Behaviour.csv"
df = pd.read_csv(DATA_PATH)

def display_dataset_preview():
    print("\n--- Dataset Preview ---")
    print(df.head())

def display_visualisation():
    print("\n--- Data Visualisation ---")
    col = input("Enter column name to plot histogram: ").strip()
    if col in df.columns:
        df[col].hist()
        plt.title(f"Histogram of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.show()
    else:
        print("Column not found.")

def search_data():
    print("\n--- Search/Filter Data ---")
    col = input("Enter column name to search: ").strip()
    val = input("Enter value to search for: ").strip()
    if col in df.columns:
        results = df[df[col].astype(str).str.contains(val, case=False)]
        print(results)
    else:
        print("Column not found.")

def update_data_entry():
    print("\n--- Update Data Entry ---")
    idx = int(input("Enter row index to update: "))
    col = input("Enter column name to update: ").strip()
    new_val = input("Enter new value: ").strip()
    if col in df.columns and 0 <= idx < len(df):
        df.at[idx, col] = new_val
        print("Entry updated.")
    else:
        print("Invalid index or column.")

def save_changes():
    df.to_csv(DATA_PATH, index=False)
    print("Changes saved to CSV.")

def show_columns():
    print("\n--- Columns in Dataset ---")
    print(list(df.columns))

def main_menu():
    while True:
        print("\n=== Data Viewer Interface ===")
        print("0. Show column names")
        print("1. View dataset")
        print("2. View visualisation")
        print("3. Search or filter data")
        print("4. Update a data entry")
        print("5. Save changes")
        print("6. Exit")

        choice = input("Select an option (0-6): ").strip()

        if choice == '0':
            show_columns()
        elif choice == '1':
            display_dataset_preview()
        elif choice == '2':
            display_visualisation()
        elif choice == '3':
            search_data()
        elif choice == '4':
            update_data_entry()
        elif choice == '5':
            save_changes()
        elif choice == '6':
            print("Exiting program.")
            break
        else:
            print("Invalid selection. Please choose a number between 0 and 6.")

if __name__ == "__main__":
    main_menu()

# %% [markdown]
# ## Phase 4: Testing and Evaluating
# ---
# ### Example: Phase 4 (Testing and Evaluating)
#
# #### **SEE-I Paragraph**
#
# **State:**
# My analysis shows that students who spend a lot of time gaming each week tend to have lower marks at school.
#
#
# **Elaborate:**
# This means that when students play video games for many hours, their academic performance drops compared to those who game less. The dataset and articles and webistes that I have researched suggests there’s a link between more gaming and worse grades, etc.
#
# **Example:**
# For example, in my Gaming_Behaviour.csv dataset, students who reported gaming more than 20 hours a week had an average grade of 65%, while those who gamed less than 5 hours a week had an average of 80%.
#
# **Illustrate:**
# It’s kind of like trying to balance homework and hobbies—if you spend too much time on one, the other gets neglected. So, just like watering a plant too much can actually harm it, spending too much time gaming can hurt your school results.
#
# ---
#
# #### **Conclusion to my hypothesis**
# Based on my analysis, my dataset only shows the gaming behaviours of high school students in America, like how many hours they spend gaming, their favourite genres, and if they prefer multiplayer games. It doesn’t actually include their school marks or grades, so I can’t say for sure if excessive gaming leads to bad marks. However, by looking at the **statistics and research**, I noticed that some students and maybe even adults spend a lot of time gaming each week, and there are clear patterns in their gaming habits. While I can’t directly prove my hypothesis with this data, it does highlight how common excessive gaming is and suggests that it could be worth investigating further to see if there’s a real link between gaming and academic performance.
#
# ---
#
# #### **Testing My Analysis**
#
# To ensure my analysis was accurate, I performed several tests in my Jupyter Notebook:
#
# - I checked the dataset for missing or inconsistent values using `df.isnull().sum()`.
# - I tried out the user interface by running all the menu options (like viewing the dataset, searching, updating, and saving) to see if everything worked and didn’t crash.
# - I also asked a friend to try my program and see if they could find any bugs or things that didn’t make sense.
#
# ---
#
# #### **PMI Table**
#
# | **Plus (+)**                                 | **Minus (-)**                                 | **Implication (I)**                                 |
# |----------------------------------------------|-----------------------------------------------|-----------------------------------------------------|
# | Contains gaming habits data         | Does not include academic performance/grades  | Can't directly link gaming to school marks           |
# | Shows hours spent gaming per week            | May have missing or inconsistent values       | Data cleaning is needed before analysis              |
# | Includes favorite genres and platform info   | Only covers self-reported behaviours          | Possible bias in responses                           |
# | Can filter by age, gender, and country       | Limited to students who responded             | Results may not represent all high school students   |
# | Useful for identifying gaming trends         | No info on other lifestyle factors            | Can't see full impact on health or academics         |
# | Easy to visualise with graphs and charts     | Some columns may be unclear to users          | Need a good data dictionary for understanding        |
#
# ---
#
# #### **Evaluate Your Project**
# ### Evaluation of My Project
#
# #### 1. Requirements Outline
# My project meets most of the functional requirements as it lets users view, search, update, and save gaming behaviour data using a simple menu in the text user interface. The graphs and charts work well for visualising trends, and the code runs without bugs or errors. For non-functional requirements, the report is clear and easy to follow, and the user interface is straightforward. However, since my dataset doesn’t include school marks, I couldn’t directly answer my hypothesis, so the information available is a bit limited.
#
# #### 2. Peer Feedback
# After sharing my program with a friend, they said the menu was easy to use and the graphs helped them understand gaming habits a bit more. My friend suggested adding more instructions for first-time users and making error messages clearer. Peer feedback gives a better view on how my project can be improved and modified from a different perspective.
#
# #### 3. Project Management
# I managed my project by breaking it into phases: planning, coding, then testing. I kept track of tasks using a checklist and made sure to test each feature before moving on. I finished most parts on time, but spent extra time cleaning the data and fixing small bugs. Overall, my project was organised and I learned a lot about managing my time.
#
# #### 4. Data and Security
# The data is valid for showing gaming behaviours however, it could include bias or mistaken information. I checked for missing values and fixed any obvious errors. The dataset is stored as a CSV, which is easy to use but not very secure—someone could edit it directly. For better security, I could add password protection or use a database. The user interface is accessible, but could be improved with more help options or a GUI (Graphical User Interface) for users who don’t like typing commands.
#
# ---
#
# #### Summary
# Overall, my project works well for exploring gaming habits/behaviours, but it can’t directly link gaming to school marks. Peer feedback and testing helped me improve the system, and I learned about data cleaning and information about gaming. For future improvements, I would look for a better dataset which I couldn't do due to time ticking and project management as well as taking feedback and trying to make it the best as possible but couldn't with limited amount of time. In conclusion, this project has really improved my data skills using pandas, matplotlib, making an interface and python coding.
